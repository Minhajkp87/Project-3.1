# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import sqlite3
import pandas as pd
con=sqlite3.connect(r'C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\data\raw\ipl.db')

def q(sql):
    return pd.read_sql(sql,con)

# %%
def run_sql_file(path):
    with open(path,'r') as f:
        script=f.read()
        con.executescript(script)
        con.commit()
        print('ran',path)

# %%
run_sql_file('C:\\Users\\BCA\\Documents\\Sem 3\\OJT\\Project 3.1\\sql\\practice\\test.sql')
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\test.sql

# %%
run_sql_file('../sql/practice/01_nulls_and_blanks.sql')
# Out:
# ran ../sql/practice/01_nulls_and_blanks.sql

# %%
q("""select count (*) as blank_before
from deliveries
where trim(bowler_type)=''""")
# Out:
#    blank_before
# 0             8

# %%
q("""select count (*) as null_after
from v_players_clean
where field_pos_clean is null""")
# Out:
#    null_after
# 0         700

# %%
run_sql_file(r'C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\02_merge_categories.sql')
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\02_merge_categories.sql

# %%
q("""select distinct team_name
from teams
order by team_name;""")
# Out:
#                       team_name
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13      Rising Pune Supergiants
# 14  Royal Challengers Bangalore
# 15          Sunrisers Hyderabad

# %%
q("""SELECT DISTINCT team_name_clean
FROM v_teams_clean
ORDER BY team_name_clean;
""")
# Out:
#                 team_name_clean
# 0           Chennai Super Kings
# 1               Deccan Chargers
# 2                Delhi Capitals
# 3                 Gujarat Lions
# 4                Gujarat Titans
# 5          Kochi Tuskers Kerala
# 6         Kolkata Knight Riders
# 7          Lucknow Super Giants
# 8                Mumbai Indians
# 9                 Pune Warriors
# 10                 Punjab Kings
# 11             Rajasthan Royals
# 12       Rising Pune Supergiant
# 13  Royal Challengers Bangalore
# 14          Sunrisers Hyderabad

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\03_venue_names.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\03_venue_names.sql

# %%
q("""SELECT venue,COUNT(*) AS matches
FROM matches
WHERE venue IN ('Wankhede Stadium','Wankhede Stadium, Mumbai')
GROUP BY venue;""")
# Out:
#                       venue  matches
# 0          Wankhede Stadium       73
# 1  Wankhede Stadium, Mumbai       57

# %%
q("""SELECT venue, COUNT(*) AS matches
FROM matches
GROUP BY venue
ORDER BY matches DESC
LIMIT 5;""")
# Out:
#                       venue  matches
# 0              Eden Gardens       77
# 1          Wankhede Stadium       73
# 2     M Chinnaswamy Stadium       65
# 3          Feroz Shah Kotla       60
# 4  Wankhede Stadium, Mumbai       57

# %%
q("""select venue_clean, COUNT(*) AS matches
from v_matches_venue
group by venue_clean
order by matches desc
limit 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1                        Eden Gardens      104
# 2              MA Chidambaram Stadium       95
# 3               M Chinnaswamy Stadium       89
# 4  Rajiv Gandhi International Stadium       87

# %%
q("""select count(*) as rows, count(distinct venue) as names from venues;""")
# Out:
#    rows  names
# 0    63     59

# %%
q("""SELECT venue_clean,COUNT(*) AS matches
FROM  v_matches_venue
GROUP BY venue_clean
ORDER BY matches DESC LIMIT 5;""")
# Out:
#                           venue_clean  matches
# 0                    Wankhede Stadium      130
# 1                        Eden Gardens      104
# 2              MA Chidambaram Stadium       95
# 3               M Chinnaswamy Stadium       89
# 4  Rajiv Gandhi International Stadium       87

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\04_dedupe_venues.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\04_dedupe_venues.sql

# %%
q("""SELECT COUNT(*) AS rows,COUNT(DISTINCT venue) AS names
FROM v_venues_clean;""")
# Out:
#    rows  names
# 0    59     59

# %%
q("""SELECT COUNT(*) AS count, venue, city
FROM v_venues_clean
GROUP BY venue
ORDER BY COUNT(*) DESC;""")
# Out:
#     count                                              venue            city
# 0       1                   Zayed Cricket Stadium, Abu Dhabi       Abu Dhabi
# 1       1                           Wankhede Stadium, Mumbai          Mumbai
# 2       1                                   Wankhede Stadium          Mumbai
# 3       1       Vidarbha Cricket Association Stadium, Jamtha          Nagpur
# 4       1                                    SuperSport Park       Centurion
# 5       1                         Subrata Roy Sahara Stadium            Pune
# 6       1                                   St George's Park  Port Elizabeth
# 7       1                               Sheikh Zayed Stadium       Abu Dhabi
# 8       1                            Sharjah Cricket Stadium         Sharjah
# 9       1   Shaheed Veer Narayan Singh International Stadium          Raipur
# 10      1                     Sawai Mansingh Stadium, Jaipur          Jaipur
# ...

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\05_city_fallback.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\05_city_fallback.sql

# %%
q("""SELECT venue,COUNT(*) AS no_city
FROM matches
WHERE city IS NULL
GROUP BY venue;
""")
# Out:
#                                  venue  no_city
# 0  Dubai International Cricket Stadium       33
# 1              Sharjah Cricket Stadium       18

# %%
q("""
SELECT city_clean
FROM v_city_clean
WHERE city_clean IS NULL;
""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""select city_clean from v_city_clean where city_clean = 'Unknown'""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""
SELECT city_clean
FROM v_city_clean
WHERE city_clean IS NULL;
""")
# Out:
# Empty DataFrame
# Columns: [city_clean]
# Index: []

# %%
q("""
SELECT city_clean
FROM v_city_clean;
""")
# Out:
#           city_clean
# 0          Bangalore
# 1          Hyderabad
# 2               Pune
# 3             Rajkot
# 4             Indore
# ...              ...
# 1207           Delhi
# 1208  New Chandigarh
# 1209          Mumbai
# 1210       Ahmedabad
# 1211          Jaipur
#
# [1212 rows x 1 columns]

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\06_season_year.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\06_season_year.sql

# %%
q("""select venue, count(*) as no_city from matches where city is null group by venue;""")
# Out:
#                                  venue  no_city
# 0  Dubai International Cricket Stadium       33
# 1              Sharjah Cricket Stadium       18

# %%
q("""SELECT season, COUNT(*) AS matches
FROM matches
WHERE season ='2020/21' 
GROUP BY season;
""")
# Out:
#     season  matches
# 0  2020/21       60

# %%
  q("""select distinct season, season_year from v_season where season = '2020/21'""")
# Out:
#     season  season_year
# 0  2020/21         2020

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\07_win_definition.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\07_win_definition.sql

# %%
run_sql_file(r"C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\08_matches_clean.sql")
# Out:
# ran C:\Users\BCA\Documents\Sem 3\OJT\Project 3.1\sql\practice\08_matches_clean.sql

# %%
q("""select * from matches_clean;""")
# Out:
#       match_id                                        venue_clean  \
# 0       335982                              M Chinnaswamy Stadium
# 1      1082591                 Rajiv Gandhi International Stadium
# 2      1082592            Maharashtra Cricket Association Stadium
# 3      1082593             Saurashtra Cricket Association Stadium
# 4      1082594                             Holkar Cricket Stadium
# ...        ...                                                ...
# 1207   1529282                               Arun Jaitley Stadium
# 1208   1529283  Maharaja Yadavindra Singh International Cricke...
# 1209   1529284                                   Wankhede Stadium
# 1210   1529285                              Narendra Modi Stadium
# 1211   1529286                             Sawai Mansingh Stadium
#
#           city_clean  season_year result                 match_winner  \
# 0          Bangalore         2008    win        Kolkata Knight Riders
# ...

# %%
import ast
import pandas as pd
d = pd.read_sql('select * from deliveries where  fielders_involved is not null', con)
d['fielders'] = d['fielders_involved'].apply(ast.literal_eval)

d = d.explode('fielders')

d['fielders'].value_counts().head(5)
# Out:
# fielders
# MS Dhoni          258
# KD Karthik        228
# RV Uthappa        169
# AB de Villiers    148
# V Kohli           142
# Name: count, dtype: int64
